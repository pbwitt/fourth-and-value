# %% [markdown]
# # Fourth & Value — Minimal Model QC
#
# This notebook auto-detects the latest `params_week*.csv` and `props_with_model_week*.csv` under `data/props/`,
# sanity-checks σ/λ, and recomputes simple model probabilities for a few spotlight players to flag degenerate 100%/0% cases.
#
# **How to use**: place this notebook in your project root and run all cells.

# %%
import pandas as pd, numpy as np, re
from pathlib import Path





params = pd.read_csv("/Users/pwitt/fourth-and-value/data/props/params_week5.csv")
merged = pd.read_csv('/Users/pwitt/fourth-and-value/data/props/props_with_model_week5.csv')
params.head(2), merged.head(2)
# Out:
# (   player_display_name             name_std  market_std  n_games  mu  sigma  \
#  0       Kyren Williams       kyren williams  anytime_td      4.0 NaN    NaN
#  1  Christian McCaffrey  christian mccaffrey  anytime_td      4.0 NaN    NaN
#
#     lam  season  week              built_at
#  0  0.5    2025     5  2025-10-02T18:56:56Z
#  1  0.5    2025     5  2025-10-02T18:56:56Z  ,
#                              game_id         commence_time         home_team  \
#  0  c4b72eabb3d557e73022ec730d8e3944  2025-10-03T00:16:00Z  Los Angeles Rams
#  1  c4b72eabb3d557e73022ec730d8e3944  2025-10-03T00:16:00Z  Los Angeles Rams
#
#               away_team                                    game   bookmaker  \
#  0  San Francisco 49ers  San Francisco 49ers @ Los Angeles Rams  draftkings
#  1  San Francisco 49ers  San Francisco 49ers @ Los Angeles Rams  draftkings
#
#    bookmaker_title         market market_std          player  ... sigma  lam  \
#  0      DraftKings  player_1st_td     1st_td  Kyren Williams  ...   NaN  NaN
#  1      DraftKings  player_1st_td     1st_td      Puka Nacua  ...   NaN  NaN
#
#     model_prob model_line  mkt_prob fair_odds  edge_bps  has_edge  season  week
#  0         NaN        NaN  0.217391       NaN       NaN     False    2025     5
#  1         NaN        NaN  0.153846       NaN       NaN     False    2025     5
#
#  [2 rows x 28 columns])

# %%
# σ/λ health
import numpy as np
def pct(x): return f"{100*float(x):.1f}%"
health = {
    "params_rows": len(params),
    "merged_rows": len(merged),
    "sigma_null%": pct(params["sigma"].isna().mean()) if "sigma" in params.columns else "NA",
    "sigma_le0%":  pct(params["sigma"].fillna(0).le(0).mean()) if "sigma" in params.columns else "NA",
    "lam_null%":   pct(params["lam"].isna().mean()) if "lam" in params.columns else "NA",
    "lam_le0%":    pct(params["lam"].fillna(0).le(0).mean()) if "lam" in params.columns else "NA",
    "model_prob_1%": pct((merged.get("model_prob", np.nan)==1.0).mean()) if "model_prob" in merged.columns else "NA",
    "model_prob_0%": pct((merged.get("model_prob", np.nan)==0.0).mean()) if "model_prob" in merged.columns else "NA",
}
pd.DataFrame([health])
# Out:
#    params_rows  merged_rows sigma_null% sigma_le0% lam_null% lam_le0%  \
# 0          898         9099       55.1%      55.1%     59.4%    80.2%
#
#   model_prob_1% model_prob_0%
# 0          0.2%         10.2%

# %%
# Recompute simple model prob to flag degeneracy for a few players
from math import erf, isfinite
def std_norm_cdf(z): return 0.5*(1.0+erf(z/np.sqrt(2.0)))
def normal_over_prob(mu, sigma, line):
    if not (np.isfinite(mu) and np.isfinite(sigma) and np.isfinite(line)): return np.nan
    if sigma <= 0: return 1.0 if mu > line else 0.0
    z = (line - mu)/sigma
    return 1.0 - std_norm_cdf(z)
def poisson_sf(lam, k):
    if not (np.isfinite(lam) and np.isfinite(k)): return np.nan
    if lam < 0: return np.nan
    sigma = np.sqrt(max(lam, 1e-9))
    return normal_over_prob(lam, sigma, k - 0.5)

NORMAL = {"rush_yds","recv_yds","pass_yds","receptions","rush_attempts","pass_attempts","pass_completions"}
POISSON = {"pass_tds","pass_interceptions","anytime_td"}

def qc_prob(row):
    m = str(row.get("market_std","")).strip().lower()
    side = str(row.get("side","")).strip().lower()
    line = row.get("point", np.nan)
    mu = row.get("mu", np.nan)
    sigma = row.get("sigma", np.nan)
    lam = row.get("lam", np.nan)
    if m in NORMAL:
        p_over = normal_over_prob(mu, sigma, line)
        return p_over if side in ("over","yes","") else (1.0 - p_over)
    if m in POISSON:
        try: k = int(np.floor(line))
        except Exception: k = np.nan
        p_ge = poisson_sf(lam, k)
        return p_ge if side in ("over","yes","") else (1.0 - p_ge)
    return np.nan

players = ["Mac Jones", "Christian McCaffrey", "Skyy Moore", "Puka Nacua"]
for c in ["mu","sigma","lam"]:
    if c not in merged.columns: merged[c] = np.nan

focus = merged[merged["player"].astype(str).str.contains("|".join(players), case=False, na=False)].copy()
focus["qc_model_prob"] = focus.apply(qc_prob, axis=1)
focus["sigma_flag"] = (focus["sigma"].fillna(0) <= 0).map({True:"σ<=0", False:"ok"})
focus["degenerate_prob"] = np.where((focus["qc_model_prob"]>=0.9999)|(focus["qc_model_prob"]<=0.0001), "EXTREME", "")
cols = ["game","player","market_std","side","point","price","mu","sigma","lam","model_prob","qc_model_prob","edge_bps","commence_time","sigma_flag","degenerate_prob"]
focus.sort_values(["player","market_std","side"])[cols].head(50)
# Out:
#                                         game               player  \
# 3     San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 104   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 184   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 262   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 407   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 559   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 30    San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 134   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 208   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 289   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 365   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 442   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 523   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 588   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 58    San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 234   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 317   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 459   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 617   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 647   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 747   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 917   San Francisco 49ers @ Los Angeles Rams  Christian McCaffrey
# 747   reception_longest   over   17.5   -105    NaN        NaN  NaN
# 917   reception_longest   over   17.5   -106    NaN        NaN  NaN
# 1059  reception_longest   over   17.5   -115    NaN        NaN  NaN
# 648   reception_longest  under   17.5   -125    NaN        NaN  NaN
# 748   reception_longest  under   17.5   -125    NaN        NaN  NaN
# 918   reception_longest  under   17.5   -125    NaN        NaN  NaN
# 1060  reception_longest  under   17.5   -115    NaN        NaN  NaN
# 687          receptions   over    6.5   -122   7.75   2.061553  NaN
# 813          receptions   over    6.5   -150   7.75   2.061553  NaN
# 889          receptions   over    6.5   -141   7.75   2.061553  NaN
# 955          receptions   over    7.5    126   7.75   2.061553  NaN
# 1014         receptions   over    6.5   -135   7.75   2.061553  NaN
# 1081         receptions   over    6.5   -150   7.75   2.061553  NaN
# 1197         receptions   over    7.5    120   7.75   2.061553  NaN
# 688          receptions  under    6.5   -104   7.75   2.061553  NaN
# 814          receptions  under    6.5    115   7.75   2.061553  NaN
# 890          receptions  under    6.5    100   7.75   2.061553  NaN
# 956          receptions  under    7.5   -160   7.75   2.061553  NaN
# 1013         receptions  under    6.5    104   7.75   2.061553  NaN
# 1082         receptions  under    6.5    114   7.75   2.061553  NaN
# 1198         receptions  under    7.5   -160   7.75   2.061553  NaN
# 669            recv_yds   over   53.5   -114  76.25  18.117671  NaN
# 771            recv_yds   over   51.5   -118  76.25  18.117671  NaN
# 877            recv_yds   over   53.5   -117  76.25  18.117671  NaN
# 933            recv_yds   over   53.5   -112  76.25  18.117671  NaN
# 993            recv_yds   over   54.5   -114  76.25  18.117671  NaN
# 1073           recv_yds   over   53.5   -114  76.25  18.117671  NaN
# 1173           recv_yds   over   55.5   -110  76.25  18.117671  NaN
# 670            recv_yds  under   53.5   -110  76.25  18.117671  NaN
# 772            recv_yds  under   51.5   -115  76.25  18.117671  NaN
#
#       model_prob  qc_model_prob  edge_bps         commence_time sigma_flag  \
# 3            NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 104          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 184          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 262          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 407          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 559          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 30      0.393469            NaN   -1303.4  2025-10-03T00:16:00Z       σ<=0
# 134     0.393469            NaN   -1898.6  2025-10-03T00:16:00Z       σ<=0
# 208     0.393469            NaN   -1303.4  2025-10-03T00:16:00Z       σ<=0
# 289     0.393469            NaN   -1187.3  2025-10-03T00:16:00Z       σ<=0
# 365     0.393469            NaN   -1326.0  2025-10-03T00:16:00Z       σ<=0
# 442     0.393469            NaN   -1540.4  2025-10-03T00:16:00Z       σ<=0
# 523     0.393469            NaN   -1392.4  2025-10-03T00:16:00Z       σ<=0
# 588     0.393469            NaN   -1303.4  2025-10-03T00:16:00Z       σ<=0
# 58           NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 234          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 317          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 459          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 617          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 647          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 747          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 917          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 1059         NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 648          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 748          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 918          NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 1060         NaN            NaN       NaN  2025-10-03T00:16:00Z       σ<=0
# 687     0.727855       0.727855    1783.1  2025-10-03T00:16:00Z         ok
# 813     0.727855       0.727855    1278.6  2025-10-03T00:16:00Z         ok
# 889     0.727855       0.727855    1427.9  2025-10-03T00:16:00Z         ok
# 955     0.548261       0.548261    1057.8  2025-10-03T00:16:00Z         ok
# 1014    0.727855       0.727855    1533.9  2025-10-03T00:16:00Z         ok
# 1081    0.727855       0.727855    1278.6  2025-10-03T00:16:00Z         ok
# 1197    0.548261       0.548261     937.2  2025-10-03T00:16:00Z         ok
# 688     0.272145       0.272145   -2376.6  2025-10-03T00:16:00Z         ok
# 814     0.272145       0.272145   -1929.7  2025-10-03T00:16:00Z         ok
# 890     0.272145       0.272145   -2278.6  2025-10-03T00:16:00Z         ok
# 956     0.451739       0.451739   -1636.5  2025-10-03T00:16:00Z         ok
# 1013    0.272145       0.272145   -2180.5  2025-10-03T00:16:00Z         ok
# 1082    0.272145       0.272145   -1951.4  2025-10-03T00:16:00Z         ok
# 1198    0.451739       0.451739   -1636.5  2025-10-03T00:16:00Z         ok
# 669     0.895384       0.895384    3626.7  2025-10-03T00:16:00Z         ok
# 771     0.914041       0.914041    3727.6  2025-10-03T00:16:00Z         ok
# 877     0.895384       0.895384    3562.1  2025-10-03T00:16:00Z         ok
# 933     0.895384       0.895384    3670.8  2025-10-03T00:16:00Z         ok
# 993     0.885025       0.885025    3523.1  2025-10-03T00:16:00Z         ok
# 1073    0.895384       0.895384    3626.7  2025-10-03T00:16:00Z         ok
# 1173    0.873956       0.873956    3501.5  2025-10-03T00:16:00Z         ok
# 670     0.104616       0.104616   -4191.9  2025-10-03T00:16:00Z         ok
# 772     0.085959       0.085959   -4489.3  2025-10-03T00:16:00Z         ok
#
#      degenerate_prob
# 3
# 104
# 184
# 262
# 407
# 559
# 30
# 134
# 208
# 289
# 365
# 442
# 523
# 588
# 58
# 234
# 317
# 459
# 617
# 647
# 747
# 917
# 1059
# 648
# 748
# 918
# 1060
# 687
# 813
# 889
# 955
# 1014
# 1081
# 1197
# 688
# 814
# 890
# 956
# 1013
# 1082
# 1198
# 669
# 771
# 877
# 933
# 993
# 1073
# 1173
# 670
# 772

# %%
# Median σ by market to catch markets with near-zero variance
if "market_std" in params.columns and "sigma" in params.columns:
    med_sigma = (params.groupby("market_std", dropna=False)["sigma"]
                      .median()
                      .reset_index()
                      .rename(columns={"sigma":"median_sigma"})
                      .sort_values("median_sigma"))
    med_sigma.head(20)
else:
    print("params missing market_std/sigma")
